# %%
import pandas as pd
from pathlib import Path

# %%
df = pd.read_csv(Path('../Resources/Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv'))
df
# Out:
#      RegionID  SizeRank                          RegionName RegionType  \
# 0      102001         0                       United States    Country
# 1      394913         1                        New York, NY        Msa
# 2      753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3      394463         3                         Chicago, IL        Msa
# 4      394514         4               Dallas-Fort Worth, TX        Msa
# ..        ...       ...                                 ...        ...
# 906    394767       929                          Lamesa, TX        Msa
# 907    753874       930                           Craig, CO        Msa
# 908    394968       931                           Pecos, TX        Msa
# 909    395188       932                          Vernon, TX        Msa
# 910    394743       933                       Ketchikan, AK        Msa
#
#     StateName  1996-01-31  1996-02-29  1996-03-31  1996-04-30  1996-05-31  \
# ...

# %%
Austin = df[df["RegionName"] == 'Austin, TX']
Austin
# Out:
#     RegionID  SizeRank  RegionName RegionType StateName  1996-01-31  \
# 35    394355        35  Austin, TX        Msa        TX    167522.0
#
#     1996-02-29  1996-03-31  1996-04-30  1996-05-31  ...  2020-10-31  \
# 35    166672.0    165453.0    163717.0    163260.0  ...    367730.0
#
#     2020-11-30  2020-12-31  2021-01-31  2021-02-28  2021-03-31  2021-04-30  \
# 35    375735.0    384071.0    392079.0    403140.0    416894.0    434403.0
#
#     2021-05-31  2021-06-30  2021-07-31
# 35    453024.0    474812.0    496659.0
#
# [1 rows x 312 columns]
