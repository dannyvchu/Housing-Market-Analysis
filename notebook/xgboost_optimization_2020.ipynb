# %%
# Import dependencies
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import tensorflow as tf
import numpy as np
from scipy import stats
from scipy.stats import norm
import seaborn as sns

# %%
# import SQL dependencies
from sqlalchemy import create_engine
import psycopg2
from pandas.io import sql

from config import db_password

db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/austin_housing"
engine = create_engine(db_string)

# %%
#pull 2020 data from pgAdmin

df = pd.read_sql('regressionzip_2020', db_string)
df.head()
# Out:
#          zpid  latestPrice  numOfBathrooms  livingAreaSqFt  numOfBedrooms  \
# 0   120900430     295000.0             2.0          1768.0              4
# 1  2080105342     309045.0             2.0          1446.0              3
# 2   241932337     315000.0             3.0          2432.0              4
# 3   241932327     279900.0             2.0          1580.0              3
# 4    69808966     239900.0             2.0          1762.0              4
#
#    avgSchoolRating  numOfStories  MedianStudentsPerTeacher  numOfHighSchools  \
# 0         2.666667             1                        14                 1
# 1         4.000000             1                        14                 1
# 2         3.666667             2                        12                 1
# 3         3.666667             1                        12                 1
# 4         3.333333             1                        14                 1
#
#    longitude  ...  lotSizeSqFt  numOfPhotos  numPriceChanges  zipcode  \
# 0 -97.661697  ...       6185.0           29                1    78660
# 1 -97.656181  ...       5161.0            2                2    78660
# 2 -97.643394  ...      12196.8           36                2    78660
# 3 -97.643288  ...       5401.0           32                2    78660
# 4 -97.623436  ...       6011.0           28                9    78617
#
#    yearBuilt  propertyTaxRate  latest_saledate  latest_salemonth  \
# 0       2013             1.98       2020-10-13                10
# 1       2020             1.98       2020-08-05                 8
# 2       2016             1.98       2020-06-11                 6
# 3       2016             1.98       2020-08-28                 8
# 4       2005             1.98       2020-09-05                 9
#
#    latest_saleyear   averagePrice
# 0             2020  303125.250000
# 1             2020  303125.250000
# 2             2020  303125.250000
# 3             2020  303125.250000
# 4             2020  198750.391304
#
# [5 rows x 23 columns]

# %%
# Import data
# df = pd.read_csv(Path('../resources/regressiondata_2020.csv'))
# df.head()

# %%
df.columns
# Out:
# Index(['zpid', 'latestPrice', 'numOfBathrooms', 'livingAreaSqFt',
#        'numOfBedrooms', 'avgSchoolRating', 'numOfStories',
#        'MedianStudentsPerTeacher', 'numOfHighSchools', 'longitude',
#        'numOfPrimarySchools', 'avgSchoolDistance', 'latitude', 'lotSizeSqFt',
#        'numOfPhotos', 'numPriceChanges', 'zipcode', 'yearBuilt',
#        'propertyTaxRate', 'latest_saledate', 'latest_salemonth',
#        'latest_saleyear', 'averagePrice'],
#       dtype='object')

# %%
# Save 'zpid'
id_df = df['zpid']

# Drop 'zpid' column for CSV
# df.drop(["zpid","latest_saledate","Unnamed: 0",'latest_salemonth','latest_saleyear'], axis = 1, inplace = True)

# Drop 'zpid' column for SQL
df.drop(["zpid","latest_saledate",'latest_salemonth','latest_saleyear'], axis = 1, inplace = True)

# Check data size after dropping the 'Id' variable
print("\nData size: {} ".format(df.shape))
# Out:
# Data size: (5408, 19)

# %%
# Create features and target
y = df["latestPrice"]
X = df.drop(columns=['latestPrice'])

# %%
# Split data into train/test
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
X_train.shape
# Out:
# (4056, 18)

# %%
# Create DMatrices

dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

# %%
from sklearn.metrics import mean_absolute_error
import numpy as np

# "Learn" the mean from the training data
mean_train = np.mean(y_train)

# Get predictions on the test set
baseline_predictions = np.ones(y_test.shape) * mean_train

# Compute MAE
mae_baseline = mean_absolute_error(y_test, baseline_predictions)
print("Baseline MAE is {:.2f}".format(mae_baseline))
# Out:
# Baseline MAE is 249930.58

# %%
# Create parameters dictionary
params = {
    # Parameters that we are going to tune.
    'max_depth':6,
    'min_child_weight': 1,
    'eta':.3,
    'subsample': 1,
    'colsample_bytree': 1,
    # Other parameters
    'objective':'reg:squarederror',
}

# %%
params['eval_metric'] = "mae"

num_boost_round = 999

# %%
model = xgb.train(
    params,
    dtrain,
    num_boost_round=num_boost_round,
    evals=[(dtest, "Test")],
    early_stopping_rounds=10
)

print("Best MAE: {:.2f} with {} rounds".format(
                 model.best_score,
                 model.best_iteration+1))
# Out:
# [0]	Test-mae:384410
# Will train until Test-mae hasn't improved in 10 rounds.
# [1]	Test-mae:277526
# [2]	Test-mae:207377
# [3]	Test-mae:166760
# [4]	Test-mae:142971
# [5]	Test-mae:129057
# [6]	Test-mae:120791
# [7]	Test-mae:116987
# [8]	Test-mae:114026
# [9]	Test-mae:114196
# [10]	Test-mae:112931
# [11]	Test-mae:112096
# [12]	Test-mae:111731
# [13]	Test-mae:111357
# [14]	Test-mae:110997
# [15]	Test-mae:110803
# [16]	Test-mae:110617
# [17]	Test-mae:110579
# [18]	Test-mae:110283
# [19]	Test-mae:109961
# [20]	Test-mae:110126
# [21]	Test-mae:109979
# [22]	Test-mae:110053
# [23]	Test-mae:110085
# [24]	Test-mae:109996
# [25]	Test-mae:110002
# [26]	Test-mae:110006
# [27]	Test-mae:109762
# [28]	Test-mae:109612
# [29]	Test-mae:109358
# [30]	Test-mae:109124
# [31]	Test-mae:108930
# [32]	Test-mae:109115
# [33]	Test-mae:109482
# [34]	Test-mae:109448
# [35]	Test-mae:109564
# [36]	Test-mae:109531
# [37]	Test-mae:109518
# [38]	Test-mae:109751
# [39]	Test-mae:109815
# [40]	Test-mae:109872
# [41]	Test-mae:109491
# Stopping. Best iteration:
# [31]	Test-mae:108930
#
# Best MAE: 108929.79 with 32 rounds

# %%
# Get cross validation score with current params
cv_results = xgb.cv(
    params,
    dtrain,
    num_boost_round=num_boost_round,
    seed=42,
    nfold=5,
    metrics={'mae'},
    early_stopping_rounds=10
)
cv_results
# Out:
#     train-mae-mean  train-mae-std  test-mae-mean  test-mae-std
# 0    389378.962500    2143.697696  391467.575000  12464.652105
# 1    277606.700000    1550.447046  282213.206250  11418.659801
# 2    202703.196875    1009.789931  211372.987500   9365.078289
# 3    153949.465625     556.743834  168403.184375   8145.937810
# 4    123216.821875     256.615107  143018.453125   8449.572745
# 5    104048.370313     410.683178  128264.262500   7483.883347
# 6     92640.760937     795.527612  121012.943750   6475.507619
# 7     85619.914062    1188.072354  118011.762500   6006.335735
# 8     81038.318750    1309.177185  115693.143750   6105.455149
# 9     77235.867187    1492.767709  114215.935937   6205.700045
# 10    74480.112500    1323.616382  113242.665625   6224.482096
# 11    72298.789063    1482.360260  113021.707813   5931.764514
# 12    70679.428125    1489.285907  112515.292188   5525.091310
# 13    68953.951562    1538.709615  112142.067187   5690.023272
# 14    67589.225000    1654.596295  111900.150000   5713.732399
# 15    66161.700000    1869.915479  111766.979687   5915.852107
# 16    64551.797656    1718.081593  111219.601563   6212.531103
# 17    63127.599219    1641.506445  110810.839062   6057.420872
# 18    61792.738281    1460.855441  110501.553125   6258.741828
# 19    60878.804688    1433.679296  110334.329687   6279.840815
# 20    59955.210156    1301.825242  110213.856250   6277.449374
# 21    59306.312500    1349.814274  110093.262500   6288.686201
# 22    58252.534375    1684.928547  109924.459375   6111.788202
# 23    57206.995313    1760.150525  109796.150000   6161.127147
# 24    56512.915625    1936.205234  109864.660938   6160.777267
# 25    55682.041406    1842.218857  109725.004687   6232.610684
# 26    54749.887500    2082.880773  109583.214062   6221.287188
# 27    54012.232031    2070.437901  109532.657813   6278.094564

# %%
cv_results['test-mae-mean'].min()
# Out:
# 109532.6578126

# %%
# You can try wider intervals with a larger step between
# each value and then narrow it down. Here after several
# iteration I found that the optimal value was in the
# following ranges.
gridsearch_params = [
    (max_depth, min_child_weight)
    for max_depth in range(4,12)
    for min_child_weight in range(1,10)
]

# %%
# Define initial best params and MAE
min_mae = float("Inf")
best_params = None
for max_depth, min_child_weight in gridsearch_params:
    print("CV with max_depth={}, min_child_weight={}".format(
                             max_depth,
                             min_child_weight))
    # Update our parameters
    params['max_depth'] = max_depth
    params['min_child_weight'] = min_child_weight
    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed=42,
        nfold=5,
        metrics={'mae'},
        early_stopping_rounds=10
    )
    # Update best MAE
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (max_depth,min_child_weight)
print("Best params: {}, {}, MAE: {}".format(best_params[0], best_params[1], min_mae))
# Out:
# CV with max_depth=4, min_child_weight=1
# 	MAE 109232.6875 for 81 rounds
# CV with max_depth=4, min_child_weight=2
# 	MAE 112063.5515628 for 65 rounds
# CV with max_depth=4, min_child_weight=3
# 	MAE 112420.64375 for 50 rounds
# CV with max_depth=4, min_child_weight=4
# 	MAE 112191.1390624 for 38 rounds
# CV with max_depth=4, min_child_weight=5
# 	MAE 112432.9093752 for 43 rounds
# CV with max_depth=4, min_child_weight=6
# 	MAE 113804.5171874 for 49 rounds
# CV with max_depth=4, min_child_weight=7
# 	MAE 113843.925 for 37 rounds
# CV with max_depth=4, min_child_weight=8
# 	MAE 112949.2984376 for 54 rounds
# CV with max_depth=4, min_child_weight=9
# 	MAE 113793.7093748 for 73 rounds
# CV with max_depth=5, min_child_weight=1
# 	MAE 109091.0359376 for 50 rounds
# CV with max_depth=5, min_child_weight=2
# 	MAE 110930.4218746 for 54 rounds
# CV with max_depth=5, min_child_weight=3
# 	MAE 110268.82968719999 for 46 rounds
# CV with max_depth=5, min_child_weight=4
# 	MAE 113385.2031246 for 39 rounds
# CV with max_depth=5, min_child_weight=5
# 	MAE 114032.43124979999 for 43 rounds
# CV with max_depth=5, min_child_weight=6
# 	MAE 113513.8687502 for 57 rounds
# CV with max_depth=5, min_child_weight=7
# 	MAE 114916.3734374 for 61 rounds
# CV with max_depth=5, min_child_weight=8
# 	MAE 113469.58749979999 for 61 rounds
# CV with max_depth=5, min_child_weight=9
# 	MAE 113669.38125 for 30 rounds
# CV with max_depth=6, min_child_weight=1
# 	MAE 109532.6578126 for 27 rounds
# CV with max_depth=6, min_child_weight=2
# 	MAE 110236.759375 for 30 rounds
# CV with max_depth=6, min_child_weight=3
# 	MAE 110359.221875 for 41 rounds
# CV with max_depth=6, min_child_weight=4
# 	MAE 112901.725 for 37 rounds
# CV with max_depth=6, min_child_weight=5
# 	MAE 113260.1624998 for 46 rounds
# CV with max_depth=6, min_child_weight=6
# 	MAE 114915.16875 for 12 rounds
# CV with max_depth=6, min_child_weight=7
# 	MAE 114148.4062502 for 27 rounds
# CV with max_depth=6, min_child_weight=8
# 	MAE 114437.371875 for 15 rounds
# CV with max_depth=6, min_child_weight=9
# 	MAE 111500.784375 for 21 rounds
# CV with max_depth=7, min_child_weight=1
# 	MAE 109827.6609374 for 33 rounds
# CV with max_depth=7, min_child_weight=2
# 	MAE 109028.62656219999 for 36 rounds
# CV with max_depth=7, min_child_weight=3
# 	MAE 110072.3078124 for 24 rounds
# CV with max_depth=7, min_child_weight=4
# 	MAE 111962.5765624 for 35 rounds
# CV with max_depth=7, min_child_weight=5
# 	MAE 114009.1171876 for 15 rounds
# CV with max_depth=7, min_child_weight=6
# 	MAE 113474.19375 for 12 rounds
# CV with max_depth=7, min_child_weight=7
# 	MAE 114137.3421876 for 20 rounds
# CV with max_depth=7, min_child_weight=8
# 	MAE 113453.303125 for 20 rounds
# CV with max_depth=7, min_child_weight=9
# 	MAE 111652.521875 for 13 rounds
# CV with max_depth=8, min_child_weight=1
# 	MAE 109604.7625002 for 27 rounds
# CV with max_depth=8, min_child_weight=2
# 	MAE 111258.4046876 for 17 rounds
# CV with max_depth=8, min_child_weight=3
# 	MAE 111327.01875 for 31 rounds
# CV with max_depth=8, min_child_weight=4
# 	MAE 112885.6859372 for 11 rounds
# CV with max_depth=8, min_child_weight=5
# 	MAE 112592.14375 for 11 rounds
# CV with max_depth=8, min_child_weight=6
# 	MAE 114175.771875 for 11 rounds
# CV with max_depth=8, min_child_weight=7
# 	MAE 112122.1156248 for 13 rounds
# CV with max_depth=8, min_child_weight=8
# 	MAE 112572.7390624 for 10 rounds
# CV with max_depth=8, min_child_weight=9
# 	MAE 110940.3140626 for 12 rounds
# CV with max_depth=9, min_child_weight=1
# 	MAE 110887.4859378 for 25 rounds
# CV with max_depth=9, min_child_weight=2
# 	MAE 112562.0578126 for 18 rounds
# CV with max_depth=9, min_child_weight=3
# 	MAE 112368.3062502 for 12 rounds
# CV with max_depth=9, min_child_weight=4
# 	MAE 110966.5109374 for 17 rounds
# CV with max_depth=9, min_child_weight=5
# 	MAE 113290.984375 for 9 rounds
# CV with max_depth=9, min_child_weight=6
# 	MAE 112058.3671874 for 10 rounds
# CV with max_depth=9, min_child_weight=7
# 	MAE 111349.9187498 for 10 rounds
# CV with max_depth=9, min_child_weight=8
# 	MAE 111594.371875 for 9 rounds
# CV with max_depth=9, min_child_weight=9
# 	MAE 108835.4203126 for 12 rounds
# CV with max_depth=10, min_child_weight=1
# 	MAE 112762.8328128 for 13 rounds
# CV with max_depth=10, min_child_weight=2
# 	MAE 112054.3953122 for 16 rounds
# CV with max_depth=10, min_child_weight=3
# 	MAE 112992.940625 for 14 rounds
# CV with max_depth=10, min_child_weight=4
# 	MAE 113089.634375 for 11 rounds
# CV with max_depth=10, min_child_weight=5
# 	MAE 111569.2515624 for 11 rounds
# CV with max_depth=10, min_child_weight=6
# 	MAE 113442.6171874 for 11 rounds
# CV with max_depth=10, min_child_weight=7
# 	MAE 112234.7796876 for 9 rounds
# CV with max_depth=10, min_child_weight=8
# 	MAE 111913.5265626 for 9 rounds
# CV with max_depth=10, min_child_weight=9
# 	MAE 110362.0640626 for 10 rounds
# CV with max_depth=11, min_child_weight=1
# 	MAE 112760.917188 for 14 rounds
# CV with max_depth=11, min_child_weight=2
# 	MAE 111850.43124979999 for 15 rounds
# CV with max_depth=11, min_child_weight=3
# 	MAE 112849.45625 for 11 rounds
# CV with max_depth=11, min_child_weight=4
# 	MAE 112800.165625 for 12 rounds
# CV with max_depth=11, min_child_weight=5
# 	MAE 112716.8718752 for 11 rounds
# CV with max_depth=11, min_child_weight=6
# 	MAE 114065.7156248 for 11 rounds
# CV with max_depth=11, min_child_weight=7
# 	MAE 113299.2546874 for 10 rounds
# CV with max_depth=11, min_child_weight=8
# 	MAE 111369.4546876 for 9 rounds
# CV with max_depth=11, min_child_weight=9
# 	MAE 108575.3734376 for 11 rounds
# Best params: 11, 9, MAE: 108575.3734376

# %%
# Update parameters with best found parameters
params['max_depth'] = 11
params['min_child_weight'] = 9

# %%
# Tuning 'subsample' and 'colsample_bytree' parameters
# Create list of possible params
gridsearch_params = [
    (subsample, colsample)
    for subsample in [i/10. for i in range(7,11)]
    for colsample in [i/10. for i in range(7,11)]
]

# %%
min_mae = float("Inf")
best_params = None
# We start by the largest values and go down to the smallest
for subsample, colsample in reversed(gridsearch_params):
    print("CV with subsample={}, colsample={}".format(
                             subsample,
                             colsample))
    # We update our parameters
    params['subsample'] = subsample
    params['colsample_bytree'] = colsample
    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed=42,
        nfold=5,
        metrics={'mae'},
        early_stopping_rounds=10
    )
    # Update best score
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (subsample,colsample)
print("Best params: {}, {}, MAE: {}".format(best_params[0], best_params[1], min_mae))
# Out:
# CV with subsample=1.0, colsample=1.0
# 	MAE 108575.3703124 for 11 rounds
# CV with subsample=1.0, colsample=0.9
# 	MAE 110579.5453126 for 10 rounds
# CV with subsample=1.0, colsample=0.8
# 	MAE 114294.63125 for 9 rounds
# CV with subsample=1.0, colsample=0.7
# 	MAE 113844.4875002 for 9 rounds
# CV with subsample=0.9, colsample=1.0
# 	MAE 110024.6125 for 11 rounds
# CV with subsample=0.9, colsample=0.9
# 	MAE 110079.0578126 for 11 rounds
# CV with subsample=0.9, colsample=0.8
# 	MAE 114867.4687498 for 11 rounds
# CV with subsample=0.9, colsample=0.7
# 	MAE 113576.3796876 for 10 rounds
# CV with subsample=0.8, colsample=1.0
# 	MAE 110223.0734376 for 10 rounds
# CV with subsample=0.8, colsample=0.9
# 	MAE 109768.0687498 for 10 rounds
# CV with subsample=0.8, colsample=0.8
# 	MAE 110960.4343746 for 11 rounds
# CV with subsample=0.8, colsample=0.7
# 	MAE 113558.5906248 for 9 rounds
# CV with subsample=0.7, colsample=1.0
# 	MAE 110565.5468752 for 10 rounds
# CV with subsample=0.7, colsample=0.9
# 	MAE 111232.8093748 for 9 rounds
# CV with subsample=0.7, colsample=0.8
# 	MAE 114496.1203124 for 9 rounds
# CV with subsample=0.7, colsample=0.7
# 	MAE 112674.6718748 for 10 rounds
# Best params: 1.0, 1.0, MAE: 108575.3703124

# %%
# Update params dictionary
params['subsample'] = 1.0
params['colsample_bytree'] = 1.0

# %%
min_mae = float("Inf")
best_params = None
for eta in [.3, .2, .1, .05, .01, .005]:
    print("CV with eta={}".format(eta))
    # We update our parameters
    params['eta'] = eta
    # Run and time CV
    cv_results = xgb.cv(
            params,
            dtrain,
            num_boost_round=num_boost_round,
            seed=42,
            nfold=5,
            metrics=['mae'],
            early_stopping_rounds=10
    )
    # Update best score
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds\n".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = eta
print("Best params: {}, MAE: {}".format(best_params, min_mae))
# Out:
# CV with eta=0.3
# 	MAE 108575.3703124 for 11 rounds
#
# CV with eta=0.2
# 	MAE 108778.7812496 for 18 rounds
#
# CV with eta=0.1
# 	MAE 106174.81093780001 for 39 rounds
#
# CV with eta=0.05
# 	MAE 105950.6015626 for 85 rounds
#
# CV with eta=0.01
# 	MAE 105987.56875020001 for 412 rounds
#
# CV with eta=0.005
# 	MAE 106266.52499979999 for 843 rounds
#
# Best params: 0.05, MAE: 105950.6015626

# %%
# Update parameters dictionary
params['eta'] = .05

# %%
params
# Out:
# {'max_depth': 11,
#  'min_child_weight': 9,
#  'eta': 0.05,
#  'subsample': 1.0,
#  'colsample_bytree': 1.0,
#  'objective': 'reg:squarederror',
#  'eval_metric': 'mae'}

# %%
# Train the model with the tuned parameters and use test data
model = xgb.train(
    params,
    dtrain,
    num_boost_round=num_boost_round,
    evals=[(dtest, "Test")],
    early_stopping_rounds=10
)

print("Best MAE: {:.2f} in {} rounds".format(model.best_score, model.best_iteration+1))
# Out:
# [0]	Test-mae:517493
# Will train until Test-mae hasn't improved in 10 rounds.
# [1]	Test-mae:492054
# [2]	Test-mae:467775
# [3]	Test-mae:445184
# [4]	Test-mae:423530
# [5]	Test-mae:402852
# [6]	Test-mae:383571
# [7]	Test-mae:364851
# [8]	Test-mae:347346
# [9]	Test-mae:330964
# [10]	Test-mae:315542
# [11]	Test-mae:300972
# [12]	Test-mae:287399
# [13]	Test-mae:274857
# [14]	Test-mae:262431
# [15]	Test-mae:250840
# [16]	Test-mae:240127
# [17]	Test-mae:230223
# [18]	Test-mae:221043
# [19]	Test-mae:212445
# [20]	Test-mae:204247
# [21]	Test-mae:196543
# [22]	Test-mae:189563
# [23]	Test-mae:183166
# [24]	Test-mae:177113
# [25]	Test-mae:171428
# [26]	Test-mae:165986
# [27]	Test-mae:160993
# [28]	Test-mae:156266
# [29]	Test-mae:151837
# [30]	Test-mae:147665
# [31]	Test-mae:143754
# [32]	Test-mae:140115
# [33]	Test-mae:136569
# [34]	Test-mae:133473
# [35]	Test-mae:130600
# [36]	Test-mae:128000
# [37]	Test-mae:125552
# [38]	Test-mae:123185
# [39]	Test-mae:120996
# [40]	Test-mae:119416
# [41]	Test-mae:117933
# [42]	Test-mae:116524
# [43]	Test-mae:115310
# [44]	Test-mae:114135
# [45]	Test-mae:113052
# [46]	Test-mae:112186
# [47]	Test-mae:111240
# [48]	Test-mae:110358
# [49]	Test-mae:109739
# [50]	Test-mae:109021
# [51]	Test-mae:108402
# [52]	Test-mae:107901
# [53]	Test-mae:107568
# [54]	Test-mae:107144
# [55]	Test-mae:106822
# [56]	Test-mae:106441
# [57]	Test-mae:106178
# [58]	Test-mae:106004
# [59]	Test-mae:105756
# [60]	Test-mae:105689
# [61]	Test-mae:105429
# [62]	Test-mae:105305
# [63]	Test-mae:105224
# [64]	Test-mae:105095
# [65]	Test-mae:105079
# [66]	Test-mae:105066
# [67]	Test-mae:104939
# [68]	Test-mae:104929
# [69]	Test-mae:104840
# [70]	Test-mae:104791
# [71]	Test-mae:104791
# [72]	Test-mae:104758
# [73]	Test-mae:104785
# [74]	Test-mae:104797
# [75]	Test-mae:104873
# [76]	Test-mae:104820
# [77]	Test-mae:104900
# [78]	Test-mae:104911
# [79]	Test-mae:104893
# [80]	Test-mae:104941
# [81]	Test-mae:104931
# [82]	Test-mae:104881
# Stopping. Best iteration:
# [72]	Test-mae:104758
#
# Best MAE: 104758.13 in 73 rounds

# %%
# Save model with best parameters
num_boost_round = model.best_iteration + 1
best_model = xgb.train(
    params,
    dtrain,
    num_boost_round=num_boost_round,
    evals=[(dtest, "Test")]
)
# Out:
# [0]	Test-mae:517493
# [1]	Test-mae:492054
# [2]	Test-mae:467775
# [3]	Test-mae:445184
# [4]	Test-mae:423530
# [5]	Test-mae:402852
# [6]	Test-mae:383571
# [7]	Test-mae:364851
# [8]	Test-mae:347346
# [9]	Test-mae:330964
# [10]	Test-mae:315542
# [11]	Test-mae:300972
# [12]	Test-mae:287399
# [13]	Test-mae:274857
# [14]	Test-mae:262431
# [15]	Test-mae:250840
# [16]	Test-mae:240127
# [17]	Test-mae:230223
# [18]	Test-mae:221043
# [19]	Test-mae:212445
# [20]	Test-mae:204247
# [21]	Test-mae:196543
# [22]	Test-mae:189563
# [23]	Test-mae:183166
# [24]	Test-mae:177113
# [25]	Test-mae:171428
# [26]	Test-mae:165986
# [27]	Test-mae:160993
# [28]	Test-mae:156266
# [29]	Test-mae:151837
# [30]	Test-mae:147665
# [31]	Test-mae:143754
# [32]	Test-mae:140115
# [33]	Test-mae:136569
# [34]	Test-mae:133473
# [35]	Test-mae:130600
# [36]	Test-mae:128000
# [37]	Test-mae:125552
# [38]	Test-mae:123185
# [39]	Test-mae:120996
# [40]	Test-mae:119416
# [41]	Test-mae:117933
# [42]	Test-mae:116524
# [43]	Test-mae:115310
# [44]	Test-mae:114135
# [45]	Test-mae:113052
# [46]	Test-mae:112186
# [47]	Test-mae:111240
# [48]	Test-mae:110358
# [49]	Test-mae:109739
# [50]	Test-mae:109021
# [51]	Test-mae:108402
# [52]	Test-mae:107901
# [53]	Test-mae:107568
# [54]	Test-mae:107144
# [55]	Test-mae:106822
# [56]	Test-mae:106441
# [57]	Test-mae:106178
# [58]	Test-mae:106004
# [59]	Test-mae:105756
# [60]	Test-mae:105689
# [61]	Test-mae:105429
# [62]	Test-mae:105305
# [63]	Test-mae:105224
# [64]	Test-mae:105095
# [65]	Test-mae:105079
# [66]	Test-mae:105066
# [67]	Test-mae:104939
# [68]	Test-mae:104929
# [69]	Test-mae:104840
# [70]	Test-mae:104791
# [71]	Test-mae:104791
# [72]	Test-mae:104758

# %%
# Create prediction
y_pred = best_model.predict(dtest)

# %%
# Save model
best_model.save_model("xgboost_optimal_2020.model")

# %%
# Calculate R squared and Adjusted R Square
import statsmodels.api as sm
result = sm.OLS(y_pred, y_test).fit()
print(result.rsquared, result.rsquared_adj)
# Out:
# 0.8795607376797697 0.8794715894471122

# %%
# Calculate Mean Squared Error
from sklearn.metrics import mean_squared_error, mean_squared_log_error
import math
print(mean_squared_error(y_test, y_pred))
print(math.sqrt(mean_squared_error(y_test, y_pred)))
print(mean_squared_log_error(y_test, y_pred))
# Out:
# 59636412900.195786
# 244205.6774528303
# 0.06288311531430633

# %%
# Calculate Mean Absolute Error(MAE)
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(y_test, y_pred))
# Out:
# 104758.1213133321

# %%
xgb.plot_importance(best_model)
plt.rcParams['figure.figsize'] = [5, 5]
plt.show()

# %%
# # Code to load model for other datasets:
# loaded_model = xgb.Booster()
# loaded_model.load_model("my_model.model")
# # And use it for predictions.
# loaded_model.predict(dtest)
