# %%
# Import dependencies
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import tensorflow as tf
import numpy as np
from scipy import stats
from scipy.stats import norm
import seaborn as sns

# %%
# import SQL dependencies
from sqlalchemy import create_engine
import psycopg2
from pandas.io import sql

from config import db_password

db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/austin_housing"
engine = create_engine(db_string)

# %%
#pull 2020 data from pgAdmin

df = pd.read_sql('regressionzip_2020', db_string)
df.head()
# Out:
#          zpid  latestPrice  numOfBathrooms  livingAreaSqFt  numOfBedrooms  \
# 0   120900430     295000.0             2.0          1768.0              4
# 1  2080105342     309045.0             2.0          1446.0              3
# 2   241932337     315000.0             3.0          2432.0              4
# 3   241932327     279900.0             2.0          1580.0              3
# 4    69808966     239900.0             2.0          1762.0              4
#
#    avgSchoolRating  numOfStories  MedianStudentsPerTeacher  numOfHighSchools  \
# 0         2.666667             1                        14                 1
# 1         4.000000             1                        14                 1
# 2         3.666667             2                        12                 1
# 3         3.666667             1                        12                 1
# 4         3.333333             1                        14                 1
#
#    longitude  ...  lotSizeSqFt  numOfPhotos  numPriceChanges  zipcode  \
# 0 -97.661697  ...       6185.0           29                1    78660
# 1 -97.656181  ...       5161.0            2                2    78660
# 2 -97.643394  ...      12196.8           36                2    78660
# 3 -97.643288  ...       5401.0           32                2    78660
# 4 -97.623436  ...       6011.0           28                9    78617
#
#    yearBuilt  propertyTaxRate  latest_saledate  latest_salemonth  \
# 0       2013             1.98       2020-10-13                10
# 1       2020             1.98       2020-08-05                 8
# 2       2016             1.98       2020-06-11                 6
# 3       2016             1.98       2020-08-28                 8
# 4       2005             1.98       2020-09-05                 9
#
#    latest_saleyear   averagePrice
# 0             2020  303125.250000
# 1             2020  303125.250000
# 2             2020  303125.250000
# 3             2020  303125.250000
# 4             2020  198750.391304
#
# [5 rows x 23 columns]

# %%
# Import data
# df = pd.read_csv(Path('../resources/regressiondata_2020.csv'))
# df.head()

# %%
df.columns
# Out:
# Index(['zpid', 'latestPrice', 'numOfBathrooms', 'livingAreaSqFt',
#        'numOfBedrooms', 'avgSchoolRating', 'numOfStories',
#        'MedianStudentsPerTeacher', 'numOfHighSchools', 'longitude',
#        'numOfPrimarySchools', 'avgSchoolDistance', 'latitude', 'lotSizeSqFt',
#        'numOfPhotos', 'numPriceChanges', 'zipcode', 'yearBuilt',
#        'propertyTaxRate', 'latest_saledate', 'latest_salemonth',
#        'latest_saleyear', 'averagePrice'],
#       dtype='object')

# %%
# Save 'zpid'
id_df = df['zpid']

# Drop 'zpid' column for CSV
# df.drop(["zpid","latest_saledate","Unnamed: 0",'latest_salemonth','latest_saleyear'], axis = 1, inplace = True)

# Drop 'zpid' column for SQL
df.drop(["zpid","latest_saledate",'latest_salemonth','latest_saleyear'], axis = 1, inplace = True)

# Check data size after dropping the 'Id' variable
print("\nData size: {} ".format(df.shape))
# Out:
# Data size: (5412, 19)

# %%
# Create features and target
y = df["latestPrice"]
X = df.drop(columns=['latestPrice'])

# %%
# Split data into train/test
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
X_train.shape
# Out:
# (4059, 18)

# %%
# Create DMatrices

dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

# %%
from sklearn.metrics import mean_absolute_error
import numpy as np

# "Learn" the mean from the training data
mean_train = np.mean(y_train)

# Get predictions on the test set
baseline_predictions = np.ones(y_test.shape) * mean_train

# Compute MAE
mae_baseline = mean_absolute_error(y_test, baseline_predictions)
print("Baseline MAE is {:.2f}".format(mae_baseline))
# Out:
# Baseline MAE is 246150.68

# %%
# Create parameters dictionary
params = {
    # Parameters that we are going to tune.
    'max_depth':6,
    'min_child_weight': 1,
    'eta':.3,
    'subsample': 1,
    'colsample_bytree': 1,
    # Other parameters
    'objective':'reg:squarederror',
}

# %%
params['eval_metric'] = "mae"

num_boost_round = 999

# %%
model = xgb.train(
    params,
    dtrain,
    num_boost_round=num_boost_round,
    evals=[(dtest, "Test")],
    early_stopping_rounds=10
)

print("Best MAE: {:.2f} with {} rounds".format(
                 model.best_score,
                 model.best_iteration+1))
# Out:
# [0]	Test-mae:383477
# Will train until Test-mae hasn't improved in 10 rounds.
# [1]	Test-mae:272696
# [2]	Test-mae:202781
# [3]	Test-mae:162918
# [4]	Test-mae:139655
# [5]	Test-mae:126078
# [6]	Test-mae:118320
# [7]	Test-mae:115663
# [8]	Test-mae:113834
# [9]	Test-mae:112197
# [10]	Test-mae:111753
# [11]	Test-mae:110739
# [12]	Test-mae:110092
# [13]	Test-mae:108941
# [14]	Test-mae:109203
# [15]	Test-mae:108840
# [16]	Test-mae:108284
# [17]	Test-mae:107688
# [18]	Test-mae:107162
# [19]	Test-mae:107380
# [20]	Test-mae:107554
# [21]	Test-mae:107317
# [22]	Test-mae:106899
# [23]	Test-mae:106975
# [24]	Test-mae:106868
# [25]	Test-mae:106388
# [26]	Test-mae:106068
# [27]	Test-mae:106214
# [28]	Test-mae:106146
# [29]	Test-mae:106302
# [30]	Test-mae:106122
# [31]	Test-mae:106023
# [32]	Test-mae:106056
# [33]	Test-mae:106226
# [34]	Test-mae:106145
# [35]	Test-mae:106277
# [36]	Test-mae:106252
# [37]	Test-mae:106415
# [38]	Test-mae:106399
# [39]	Test-mae:106460
# [40]	Test-mae:106145
# [41]	Test-mae:106287
# Stopping. Best iteration:
# [31]	Test-mae:106023
#
# Best MAE: 106022.81 with 32 rounds

# %%
# Get cross validation score with current params
cv_results = xgb.cv(
    params,
    dtrain,
    num_boost_round=num_boost_round,
    seed=42,
    nfold=5,
    metrics={'mae'},
    early_stopping_rounds=10
)
cv_results
# Out:
#     train-mae-mean  train-mae-std  test-mae-mean  test-mae-std
# 0    389436.943750    1921.203125  390748.600000   9920.454535
# 1    277874.918750    1501.409024  282379.250000   9089.020237
# 2    203070.928125    1290.052596  212782.028125   7592.573464
# 3    154278.831250    1562.886175  170259.559375   6458.533707
# 4    123748.009375    1427.488828  145883.081250   5566.041560
# 5    104997.912500    1169.058721  131975.285937   5487.189468
# 6     93543.771875    1434.763486  124157.217187   5364.237533
# 7     86405.832812    1091.129784  120088.750000   5563.062450
# 8     81662.909375    1028.834900  117912.837500   5723.502061
# 9     78191.968750     921.820680  116704.409375   5416.723706
# 10    75530.656250     720.046301  115986.892187   5625.449090
# 11    73466.657813    1047.341993  115477.201563   5495.844664
# 12    71696.331250    1010.828247  115012.400000   5483.519830
# 13    69968.196875    1030.844076  114840.240625   5215.012569
# 14    68343.404687    1032.240626  114786.453125   5285.024744
# 15    66743.482813    1111.362327  114347.020312   4949.364199
# 16    65445.228125    1183.427366  114352.398437   4951.635063
# 17    63963.073438     973.255284  114064.740625   4772.341062
# 18    62855.342969     945.117264  113745.181250   4751.520036
# 19    61787.451562    1182.242594  113740.901562   4814.254241
# 20    60562.867969    1138.926394  113276.851562   5222.708162
# 21    59787.878125    1035.496124  113241.229688   5254.081071
# 22    58927.432812    1105.939502  113196.453125   5136.200515
# 23    58148.249219    1128.370450  113072.465625   5108.325574

# %%
cv_results['test-mae-mean'].min()
# Out:
# 113072.4656252

# %%
# You can try wider intervals with a larger step between
# each value and then narrow it down. Here after several
# iteration I found that the optimal value was in the
# following ranges.
gridsearch_params = [
    (max_depth, min_child_weight)
    for max_depth in range(4,12)
    for min_child_weight in range(1,10)
]

# %%
# Define initial best params and MAE
min_mae = float("Inf")
best_params = None
for max_depth, min_child_weight in gridsearch_params:
    print("CV with max_depth={}, min_child_weight={}".format(
                             max_depth,
                             min_child_weight))
    # Update our parameters
    params['max_depth'] = max_depth
    params['min_child_weight'] = min_child_weight
    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed=42,
        nfold=5,
        metrics={'mae'},
        early_stopping_rounds=10
    )
    # Update best MAE
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (max_depth,min_child_weight)
print("Best params: {}, {}, MAE: {}".format(best_params[0], best_params[1], min_mae))
# Out:
# CV with max_depth=4, min_child_weight=1
# 	MAE 115247.0015628 for 81 rounds
# CV with max_depth=4, min_child_weight=2
# 	MAE 115058.5796874 for 68 rounds
# CV with max_depth=4, min_child_weight=3
# 	MAE 115358.2999998 for 49 rounds
# CV with max_depth=4, min_child_weight=4
# 	MAE 116028.3390624 for 60 rounds
# CV with max_depth=4, min_child_weight=5
# 	MAE 115177.04375 for 52 rounds
# CV with max_depth=4, min_child_weight=6
# 	MAE 118011.1531254 for 28 rounds
# CV with max_depth=4, min_child_weight=7
# 	MAE 116277.3625 for 65 rounds
# CV with max_depth=4, min_child_weight=8
# 	MAE 115077.0609376 for 63 rounds
# CV with max_depth=4, min_child_weight=9
# 	MAE 117279.5124998 for 66 rounds
# CV with max_depth=5, min_child_weight=1
# 	MAE 113077.6234376 for 32 rounds
# CV with max_depth=5, min_child_weight=2
# 	MAE 112978.7906252 for 30 rounds
# CV with max_depth=5, min_child_weight=3
# 	MAE 115124.6609376 for 43 rounds
# CV with max_depth=5, min_child_weight=4
# 	MAE 114529.6875 for 39 rounds
# CV with max_depth=5, min_child_weight=5
# 	MAE 114610.084375 for 55 rounds
# CV with max_depth=5, min_child_weight=6
# 	MAE 115924.5984374 for 45 rounds
# CV with max_depth=5, min_child_weight=7
# 	MAE 114768.3781248 for 56 rounds
# CV with max_depth=5, min_child_weight=8
# 	MAE 116113.1625 for 45 rounds
# CV with max_depth=5, min_child_weight=9
# 	MAE 115676.54375 for 54 rounds
# CV with max_depth=6, min_child_weight=1
# 	MAE 113072.46718780001 for 23 rounds
# CV with max_depth=6, min_child_weight=2
# 	MAE 114309.80625 for 34 rounds
# CV with max_depth=6, min_child_weight=3
# 	MAE 113218.9562502 for 38 rounds
# CV with max_depth=6, min_child_weight=4
# 	MAE 114040.8031248 for 50 rounds
# CV with max_depth=6, min_child_weight=5
# 	MAE 117370.140625 for 39 rounds
# CV with max_depth=6, min_child_weight=6
# 	MAE 117454.2890626 for 19 rounds
# CV with max_depth=6, min_child_weight=7
# 	MAE 112945.4296878 for 18 rounds
# CV with max_depth=6, min_child_weight=8
# 	MAE 114995.5421878 for 25 rounds
# CV with max_depth=6, min_child_weight=9
# 	MAE 116238.1078122 for 15 rounds
# CV with max_depth=7, min_child_weight=1
# 	MAE 115278.9250002 for 23 rounds
# CV with max_depth=7, min_child_weight=2
# 	MAE 113966.2296876 for 29 rounds
# CV with max_depth=7, min_child_weight=3
# 	MAE 112587.2234376 for 35 rounds
# CV with max_depth=7, min_child_weight=4
# 	MAE 113810.9656248 for 11 rounds
# CV with max_depth=7, min_child_weight=5
# 	MAE 115295.009375 for 13 rounds
# CV with max_depth=7, min_child_weight=6
# 	MAE 115482.4359374 for 23 rounds
# CV with max_depth=7, min_child_weight=7
# 	MAE 113486.6328126 for 42 rounds
# CV with max_depth=7, min_child_weight=8
# 	MAE 114061.7093748 for 12 rounds
# CV with max_depth=7, min_child_weight=9
# 	MAE 116394.8921874 for 9 rounds
# CV with max_depth=8, min_child_weight=1
# 	MAE 112730.7890624 for 28 rounds
# CV with max_depth=8, min_child_weight=2
# 	MAE 113389.81875 for 27 rounds
# CV with max_depth=8, min_child_weight=3
# 	MAE 112827.5828126 for 14 rounds
# CV with max_depth=8, min_child_weight=4
# 	MAE 114099.34375 for 11 rounds
# CV with max_depth=8, min_child_weight=5
# 	MAE 113709.3484376 for 11 rounds
# CV with max_depth=8, min_child_weight=6
# 	MAE 113703.675 for 10 rounds
# CV with max_depth=8, min_child_weight=7
# 	MAE 114630.9749998 for 11 rounds
# CV with max_depth=8, min_child_weight=8
# 	MAE 111261.9265626 for 11 rounds
# CV with max_depth=8, min_child_weight=9
# 	MAE 113724.6921874 for 10 rounds
# CV with max_depth=9, min_child_weight=1
# 	MAE 112073.3890622 for 21 rounds
# CV with max_depth=9, min_child_weight=2
# 	MAE 113853.709375 for 23 rounds
# CV with max_depth=9, min_child_weight=3
# 	MAE 112987.6734376 for 12 rounds
# CV with max_depth=9, min_child_weight=4
# 	MAE 115173.8640626 for 15 rounds
# CV with max_depth=9, min_child_weight=5
# 	MAE 113424.746875 for 14 rounds
# CV with max_depth=9, min_child_weight=6
# 	MAE 114691.1874998 for 13 rounds
# CV with max_depth=9, min_child_weight=7
# 	MAE 113116.146875 for 15 rounds
# CV with max_depth=9, min_child_weight=8
# 	MAE 112114.201562 for 9 rounds
# CV with max_depth=9, min_child_weight=9
# 	MAE 113451.05625 for 10 rounds
# CV with max_depth=10, min_child_weight=1
# 	MAE 113971.0125002 for 17 rounds
# CV with max_depth=10, min_child_weight=2
# 	MAE 113228.51875 for 15 rounds
# CV with max_depth=10, min_child_weight=3
# 	MAE 113267.5546874 for 16 rounds
# CV with max_depth=10, min_child_weight=4
# 	MAE 114368.5734374 for 10 rounds
# CV with max_depth=10, min_child_weight=5
# 	MAE 115011.6218746 for 10 rounds
# CV with max_depth=10, min_child_weight=6
# 	MAE 114161.8250002 for 10 rounds
# CV with max_depth=10, min_child_weight=7
# 	MAE 113568.8828126 for 13 rounds
# CV with max_depth=10, min_child_weight=8
# 	MAE 111819.86562540001 for 9 rounds
# CV with max_depth=10, min_child_weight=9
# 	MAE 114727.0609376 for 9 rounds
# CV with max_depth=11, min_child_weight=1
# 	MAE 114594.9953124 for 14 rounds
# CV with max_depth=11, min_child_weight=2
# 	MAE 115113.0140626 for 15 rounds
# CV with max_depth=11, min_child_weight=3
# 	MAE 112718.24374959999 for 13 rounds
# CV with max_depth=11, min_child_weight=4
# 	MAE 113142.4375 for 11 rounds
# CV with max_depth=11, min_child_weight=5
# 	MAE 114150.1046874 for 11 rounds
# CV with max_depth=11, min_child_weight=6
# 	MAE 113486.746875 for 10 rounds
# CV with max_depth=11, min_child_weight=7
# 	MAE 113173.8093748 for 10 rounds
# CV with max_depth=11, min_child_weight=8
# 	MAE 110651.484375 for 10 rounds
# CV with max_depth=11, min_child_weight=9
# 	MAE 114099.278125 for 9 rounds
# Best params: 11, 8, MAE: 110651.484375

# %%
# Update parameters with best found parameters
params['max_depth'] = 11
params['min_child_weight'] = 8

# %%
# Tuning 'subsample' and 'colsample_bytree' parameters
# Create list of possible params
gridsearch_params = [
    (subsample, colsample)
    for subsample in [i/10. for i in range(7,11)]
    for colsample in [i/10. for i in range(7,11)]
]

# %%
min_mae = float("Inf")
best_params = None
# We start by the largest values and go down to the smallest
for subsample, colsample in reversed(gridsearch_params):
    print("CV with subsample={}, colsample={}".format(
                             subsample,
                             colsample))
    # We update our parameters
    params['subsample'] = subsample
    params['colsample_bytree'] = colsample
    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed=42,
        nfold=5,
        metrics={'mae'},
        early_stopping_rounds=10
    )
    # Update best score
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (subsample,colsample)
print("Best params: {}, {}, MAE: {}".format(best_params[0], best_params[1], min_mae))
# Out:
# CV with subsample=1.0, colsample=1.0
# 	MAE 110651.4812498 for 10 rounds
# CV with subsample=1.0, colsample=0.9
# 	MAE 112758.3328124 for 10 rounds
# CV with subsample=1.0, colsample=0.8
# 	MAE 114558.8156248 for 10 rounds
# CV with subsample=1.0, colsample=0.7
# 	MAE 115659.2468754 for 10 rounds
# CV with subsample=0.9, colsample=1.0
# 	MAE 114113.3484376 for 13 rounds
# CV with subsample=0.9, colsample=0.9
# 	MAE 112887.915625 for 10 rounds
# CV with subsample=0.9, colsample=0.8
# 	MAE 116811.8687504 for 11 rounds
# CV with subsample=0.9, colsample=0.7
# 	MAE 115325.984375 for 12 rounds
# CV with subsample=0.8, colsample=1.0
# 	MAE 113114.7000002 for 13 rounds
# CV with subsample=0.8, colsample=0.9
# 	MAE 114355.378125 for 13 rounds
# CV with subsample=0.8, colsample=0.8
# 	MAE 117632.6453124 for 13 rounds
# CV with subsample=0.8, colsample=0.7
# 	MAE 116756.0609376 for 13 rounds
# CV with subsample=0.7, colsample=1.0
# 	MAE 113617.7937498 for 12 rounds
# CV with subsample=0.7, colsample=0.9
# 	MAE 114126.2078128 for 12 rounds
# CV with subsample=0.7, colsample=0.8
# 	MAE 117671.0328124 for 14 rounds
# CV with subsample=0.7, colsample=0.7
# 	MAE 119178.615625 for 16 rounds
# Best params: 1.0, 1.0, MAE: 110651.4812498

# %%
# Update params dictionary
params['subsample'] = 1.0
params['colsample_bytree'] = 1.0

# %%
min_mae = float("Inf")
best_params = None
for eta in [.3, .2, .1, .05, .01, .005]:
    print("CV with eta={}".format(eta))
    # We update our parameters
    params['eta'] = eta
    # Run and time CV
    cv_results = xgb.cv(
            params,
            dtrain,
            num_boost_round=num_boost_round,
            seed=42,
            nfold=5,
            metrics=['mae'],
            early_stopping_rounds=10
    )
    # Update best score
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds\n".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = eta
print("Best params: {}, MAE: {}".format(best_params, min_mae))
# Out:
# CV with eta=0.3
# 	MAE 110651.4781252 for 10 rounds
#
# CV with eta=0.2
# 	MAE 110093.86874979999 for 18 rounds
#
# CV with eta=0.1
# 	MAE 108928.3296876 for 37 rounds
#
# CV with eta=0.05
# 	MAE 107974.1359374 for 78 rounds
#
# CV with eta=0.01
# 	MAE 107952.53125 for 399 rounds
#
# CV with eta=0.005
# 	MAE 108024.8484372 for 821 rounds
#
# Best params: 0.01, MAE: 107952.53125

# %%
# Update parameters dictionary
params['eta'] = .01

# %%
params
# Out:
# {'max_depth': 11,
#  'min_child_weight': 8,
#  'eta': 0.01,
#  'subsample': 1.0,
#  'colsample_bytree': 1.0,
#  'objective': 'reg:squarederror',
#  'eval_metric': 'mae'}

# %%
# Train the model with the tuned parameters and use test data
model = xgb.train(
    params,
    dtrain,
    num_boost_round=num_boost_round,
    evals=[(dtest, "Test")],
    early_stopping_rounds=10
)

print("Best MAE: {:.2f} in {} rounds".format(model.best_score, model.best_iteration+1))
# Out:
# [0]	Test-mae:539524
# Will train until Test-mae hasn't improved in 10 rounds.
# [1]	Test-mae:534229
# [2]	Test-mae:529012
# [3]	Test-mae:523848
# [4]	Test-mae:518734
# [5]	Test-mae:513667
# [6]	Test-mae:508623
# [7]	Test-mae:503610
# [8]	Test-mae:498689
# [9]	Test-mae:493743
# [10]	Test-mae:488938
# [11]	Test-mae:484132
# [12]	Test-mae:479392
# [13]	Test-mae:474683
# [14]	Test-mae:470068
# [15]	Test-mae:465453
# [16]	Test-mae:460948
# [17]	Test-mae:456422
# [18]	Test-mae:451970
# [296]	Test-mae:100761
# [297]	Test-mae:100724
# [298]	Test-mae:100690
# [299]	Test-mae:100659
# [300]	Test-mae:100621
# [301]	Test-mae:100581
# [302]	Test-mae:100542
# [303]	Test-mae:100506
# [304]	Test-mae:100468
# [305]	Test-mae:100434
# [306]	Test-mae:100403
# [307]	Test-mae:100370
# [308]	Test-mae:100343
# [309]	Test-mae:100314
# [310]	Test-mae:100276
# [311]	Test-mae:100257
# [312]	Test-mae:100223
# [313]	Test-mae:100189
# [314]	Test-mae:100169
# [315]	Test-mae:100124
# [316]	Test-mae:100070
# [317]	Test-mae:100055
# [318]	Test-mae:100027
# [319]	Test-mae:100009
# [320]	Test-mae:99960.1
# [321]	Test-mae:99948.3
# [322]	Test-mae:99898.3
# [323]	Test-mae:99863.8
# [324]	Test-mae:99847.2
# [325]	Test-mae:99814
# [326]	Test-mae:99825.9
# [327]	Test-mae:99771.8
# [328]	Test-mae:99742.5
# [329]	Test-mae:99758.8
# [330]	Test-mae:99738.1
# [331]	Test-mae:99756.4
# [332]	Test-mae:99739.5
# [333]	Test-mae:99720.3
# [334]	Test-mae:99728.6
# [335]	Test-mae:99693.8
# [336]	Test-mae:99717.1
# [337]	Test-mae:99723.4
# [338]	Test-mae:99734.7
# [339]	Test-mae:99693.9
# [340]	Test-mae:99693.5
# [341]	Test-mae:99716
# [342]	Test-mae:99685.3
# [343]	Test-mae:99696.8
# [344]	Test-mae:99699.4
# [345]	Test-mae:99669.4
# [346]	Test-mae:99685.3
# [347]	Test-mae:99661
# [348]	Test-mae:99680.9
# [349]	Test-mae:99654.3
# [350]	Test-mae:99633.3
# [351]	Test-mae:99644.5
# [352]	Test-mae:99621.2
# [353]	Test-mae:99600.2
# [354]	Test-mae:99626
# [355]	Test-mae:99604.8
# [356]	Test-mae:99621.6
# [357]	Test-mae:99592.4
# [358]	Test-mae:99576.1
# [359]	Test-mae:99593.2
# [360]	Test-mae:99564.9

# %%
# Create prediction
y_pred = best_model.predict(dtest)

# %%
# Save model
best_model.save_model("xgboost_optimal_2020.model")

# %%
# Calculate R squared and Adjusted R Square
import statsmodels.api as sm
result = sm.OLS(y_pred, y_test).fit()
print(result.rsquared, result.rsquared_adj)
# Out:
# 0.8954463408211364 0.8953690082329864

# %%
# Calculate Mean Squared Error
from sklearn.metrics import mean_squared_error, mean_squared_log_error
import math
print(mean_squared_error(y_test, y_pred))
print(math.sqrt(mean_squared_error(y_test, y_pred)))
print(mean_squared_log_error(y_test, y_pred))
# Out:
# 49667940026.47127
# 222863.05217884653
# 0.06019869223871155

# %%
# Calculate Mean Absolute Error(MAE)
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(y_test, y_pred))
# Out:
# 99564.86546101257

# %%
import matplotlib.pyplot as plt

# extra step to allow graphviz to be found 
import os
os.environ["PATH"] += os.pathsep + 'C:/Users/danny/.conda/envs/mlenv/lib/site-packages/graphviz'

xgb.plot_tree(model, num_trees=0)
plt.rcParams['figure.figsize'] = [50, 10]
plt.show()

# %%
xgb.plot_importance(best_model)
plt.rcParams['figure.figsize'] = [5, 5]
plt.show()

# %%
# # Code to load model for other datasets:
# loaded_model = xgb.Booster()
# loaded_model.load_model("my_model.model")
# # And use it for predictions.
# loaded_model.predict(dtest)
